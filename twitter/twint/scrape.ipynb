# %%
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
c = twint.Config()

c.Search = ['Taylor Swift']
c.Limit = 1000
c.Min_likes = 5
c.Store_csv = True
c.Output = "ts.csv"
twint.run.Search(c)
# Out:
# 1517568560318590977 2022-04-23 01:18:34 +0700 <GREASESTAlNS> the traffic light talking to taylor swift when she asked if it would be alright   https://t.co/1VoT5z0Nql
# 1517567366745530371 2022-04-23 01:13:49 +0700 <ladygaga_chart> Artists who won the most #EMAs  #1. Lady gaga — 12 wins #2. Britney spears , Taylor swift — 8 wins #3. Beyonce — 7 wins  https://t.co/L9tmITFudI
# 1517567172431826951 2022-04-23 01:13:03 +0700 <TSWorId> Really weird that there are so many interactions between Taylor Swift and other artists these days... Something big is coming up? 👀👀👀  https://t.co/hoPsQr0UV4
# ...

# %%
c = twint.Config()

c.Username = 'wlopwangling'

c.Since = '2013-05-04'
c.Until = '2022-04-14'
c.limit = 200
c.Store_csv = True
c.Output = "wlop.csv"
twint.run.Search(c)
# Out:
# 1513745724365676549 2022-04-12 12:07:59 +0700 <wlopwangling> Photoshop painting process - Mahina1  https://t.co/C1JuW85D2N via @YouTube
# 1510132898585726979 2022-04-02 12:51:54 +0700 <wlopwangling> Home sweet home #Mahina #CloudInsect  https://t.co/yLmUKQ9pbO
# 1505991496901685248 2022-03-22 02:35:27 +0700 <wlopwangling> I only sell my NFTs on  https://t.co/YbFAXPMjnb  and   https://t.co/M0YaEtsVZo  All the accounts on other platforms are fake! Collectors please be careful, contact me to confirm before you buy any NFT arts under my name!  https://t.co/PoHuFuIJtA
# 1502565545064861696 2022-03-12 15:41:56 +0700 <wlopwangling> Photoshop painting process - Sunshine2  https://t.co/5NYFgFK1kU via @YouTube
# 1500717963791384577 2022-03-07 13:20:19 +0700 <wlopwangling> To the ocean #Ghostblade #PrincessYulia  https://t.co/npKhqkjPQb
# 1493878458778537984 2022-02-16 16:22:34 +0700 <wlopwangling> @DangaiBleachigo 😂
# ...

# %%
c = twint.Config()
c.Username = "wlopwangling"
c.Custom["user"] = ["id", "username",'tweets','followers']
c.Output = "wlopwangling.csv"
c.Store_csv = True

twint.run.Lookup(c)
# Out:
# 987978757 | WLOP | @wlopwangling | Private: False | Verified: False | Bio: Painting videos and Tutorials: https://t.co/6cq1snzuyG NFTs:  Foundation:https://t.co/GEs8i942Gg SuperRare: https://t.co/AcAmdDTjQD Gallery: https://t.co/BVa92S37vf | Location:  | Url: https://t.co/vlmIqYVS1a | Joined: 2012-12-04 03:50:50 UTC | Tweets: 603 | Following: 142 | Followers: 543696 | Likes: 35 | Media: 355 | Avatar: https://pbs.twimg.com/profile_images/916939669471862784/SD0xYKa-_normal.jpg

# %%
import pandas as pd 
tweets = pd.read_csv('taylor_swift_tweets.csv')
tweets.head(5)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                     id      conversation_id  \
# 0  1514626874739249154  1514626874739249154
# 1  1514626857651490821  1514626857651490821
# 2  1514626848126296068  1514626848126296068
# 3  1514626837544157189  1514626837544157189
# 4  1514626803150712833  1330575546208686080
#
#                                   created_at        date      time  timezone  \
# 0  2022-04-14 22:29:22 SE Asia Standard Time  2022-04-14  22:29:22       700
# 1  2022-04-14 22:29:17 SE Asia Standard Time  2022-04-14  22:29:17       700
# 2  2022-04-14 22:29:15 SE Asia Standard Time  2022-04-14  22:29:15       700
# 3  2022-04-14 22:29:13 SE Asia Standard Time  2022-04-14  22:29:13       700
# ...

# %%
twt = tweets[['id','date','time','tweet']]
twt.to_csv('extracted_tweet.csv')
